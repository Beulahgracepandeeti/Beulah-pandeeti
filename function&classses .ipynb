# %%
## print a number even add

# %%
num=int (input('enter a num i will tell the number type'))
if num %2==0:
    print("the num is even")
else:
    print("the num is odd")
# Out:
# enter a num i will tell the number type667
# the num is odd

# %%
num=int (input('enter a num i will tell the number type'))
if num %2==0:
    print("the num is even")
else:
    print("the num is odd")
# Out:
# enter a num i will tell the number type32
# the num is even

# %%
2. For loop

# %%
myfriends=['swetha','sony','ram','raj']
print(myfriends)
# Out:
# ['swetha', 'sony', 'ram', 'raj']

# %%
for friend in myfriends:
    print (friend.upper())
# Out:
# SWETHA
# SONY
# RAM
# RAJ

# %%
cars=['kia','bmw','maruthi','toyota ']
print (cars)
# Out:
# ['kia', 'bmw', 'maruthi', 'toyota ']

# %%
for car in cars:
    print(car.upper())
# Out:
# KIA
# BMW
# MARUTHI
# TOYOTA

# %%
## to printlia in upper case remaining in lower case

# %%
cars=['kia','bmw','maruthi','toyota ']
print (cars)
# Out:
# ['kia', 'bmw', 'maruthi', 'toyota ']

# %%
for x in cars:
        if x=='kia':
            print(x.upper())
        else:
            print(x.lower())
# Out:
# KIA
# bmw
# maruthi
# toyota

# %%
for x in cars:
    if x=='maruthi':
        print(x.upper())
    else:
        print(x.lower())
# Out:
# kia
# bmw
# MARUTHI
# toyota

# %%
## power opertions

# %%
for i in range (1,6):
    print('2*',i,'=',i*2)
# Out:
# 2* 1 = 2
# 2* 2 = 4
# 2* 3 = 6
# 2* 4 = 8
# 2* 5 = 10

# %%
for i in range(1,9):
    print('3',i,'=',i*3)
# Out:
# 3 1 = 3
# 3 2 = 6
# 3 3 = 9
# 3 4 = 12
# 3 5 = 15
# 3 6 = 18
# 3 7 = 21
# 3 8 = 24

# %%
## FUNCTION--- is usesd exceute a task
uses ;
codye reusability
easy debuging
easily understandable

divide into 3 parts
1.function declaration
2.function calling
3.function defination

def;-keyword

# %%
def greet():
    print("hlo all how are you")

# %%
greet()
# Out:
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# hlo all how are you
# ...

# %%
## enhancement of code

# %%
def greet_username(user):
    print (f"hello good to have you,{user.upper()}")

# %%
greet_username('beulah')
# Out:
# hello good to have you,BEULAH

# %%
greet_username('teju')
# Out:
# hello good to have you,TEJU

# %%
greet_username('blessy')
# Out:
# hello good to have you,BLESSY

# %%
greet_username('anu')
# Out:
# hello good to have you,ANU

# %%
def friend():
    f_name='Beulah'
    l_name='blessy'
    print(f"my full name is {f_name}{l_name}")

# %%
 friend()
# Out:
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# my full name is Beulahblessy
# ...

# %%
##intoductoin to arguments
arguments are 4 types
1.positional arguments 
2.keyword arguments
3.default arguments
4.arbitary arguments

# %% [markdown]
# 1.postional arguments

# %%
def describe_pets(animal_type,pet_name):
    print(f"\n i have a {animal_type}")
    print(f" my {animal_type} name is {pet_name}")

# %%
describe_pets('dog','tommy')
# Out:
#  i have a dog
#  my dog name is tommy

# %%
def describe_pets(animal_type,pet_name):
    print(f"\n i have a {animal_type}")
    print(f" my {animal_type} name is {pet_name}")

# %%
describe_pets('tommy','dog')
# Out:
#  i have a tommy
#  my tommy name is dog

# %%
2.keyword arguments

# %%
def describe_pets(animal_type,pet_name):
    print(f"\n i have a {animal_type}")
    print(f" my {animal_type} name is {pet_name}")

# %%
describe_pets(animal_type='cat',pet_name='bruno')
# Out:
#  i have a cat
#  my cat name is bruno

# %%
def describe_pets(animal_type,pet_name):
    print(f"\n i have a {animal_type}")
    print(f" my {animal_type} name is {pet_name}")

# %%
describe_pets(pet_name='bruno',animal_type='cat',)
# Out:
#  i have a cat
#  my cat name is bruno

# %%
3.default arguments

# %%
def describe_pets(animal_type='dog',pet_name='roosi'):
    print(f"\n i have a {animal_type}")
    print(f" my {animal_type} name is {pet_name}")

# %%
describe_pets()
# Out:
#  i have a dog
#  my dog name is roosi

# %%
4.arbitary arguments

# %%
def greet(*msg):
    for i in msg:
        print(msg)

# %%
greet('hello','all','how','are',"you")
# Out:
# ('hello', 'all', 'how', 'are', 'you')
# ('hello', 'all', 'how', 'are', 'you')
# ('hello', 'all', 'how', 'are', 'you')
# ('hello', 'all', 'how', 'are', 'you')
# ('hello', 'all', 'how', 'are', 'you')

# %%
making a  sandwich using function

# %%
def make_sandwich(item1,item2,item3):
    print ('sandwich is preparing for you')
    print('adding {item1} to you are sandwich')
    print('adding {item2} to you are sandwich')
    print('adding {item3} to you are sandwich')
    print('your sandwich is prepared for you')

# %%
make_sandwich('butter','ghee','cheese')
make_sandwich('butter','onion','egg')
make_sandwich('tomato','bread','oil')
# Out:
# sandwich is preparing for you
# adding {item1} to you are sandwich
# adding {item2} to you are sandwich
# adding {item3} to you are sandwich
# your sandwich is prepared for you
# sandwich is preparing for you
# adding {item1} to you are sandwich
# adding {item2} to you are sandwich
# adding {item3} to you are sandwich
# your sandwich is prepared for you
# sandwich is preparing for you
# adding {item1} to you are sandwich
# adding {item2} to you are sandwich
# adding {item3} to you are sandwich
# your sandwich is prepared for you

# %%
  ## classes
  syntax 
     class classname():
        data
        funtion

# %% [markdown]
# class example():
# a=2
# b=9
# p=example()

# %%
p.a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-1a175c0d79d9> in <module>
# ----> 1 p.a
#
# NameError: name 'p' is not defined

# %%
class example():
    x=23
    k=45

# %%
p=example()

# %%
p.x
# Out:
# 23

# %%
p.k
# Out:
# 45

# %%
## using self keyword exmple programme

# %%
class fruits:
    def mango(self):
        print('it is yellow')
    def straberry(self):
        print ('it is red')

# %%
x=fruits()

# %%
x.mango()
# Out:
# it is yellow

# %%
x.straberry()
# Out:
# it is red

# %%
1.T-SHIRT

# %%
def make_shirt(shirt_type,shirt_size):
    print(f" i want stitch {shirt_type}")
    print(f"my {shirt_type}  size is {shirt_size}")

# %%
make_shirt('t-shirt','XL')
# Out:
#  i want stitch t-shirt
# my t-shirt  size is XL

# %%
make_shirt('XL','t-shirt')
# Out:
#  i want stitch XL
# my XL  size is t-shirt

# %%
2.keyword

# %%
def make_shirt(shirt_type,shirt_size):
    print(f" i want stitch {shirt_type}")
    print(f"my {shirt_type}  size is {shirt_size}")

# %%
make_shirt(shirt_type='t-shirt',shirt_size='XL')
# Out:
#  i want stitch t-shirt
# my t-shirt  size is XL

# %%
make_shirt(shirt_size='XL',shirt_type='tshirt')
# Out:
#  i want stitch tshirt
# my tshirt  size is XL

# %% [markdown]
# 2.LARGE SHIRT
